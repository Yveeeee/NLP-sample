# %% [markdown]
# # Text Classification
#
# This program allows you to train 3 different Naive Bayes classifiers to do the chunk text classification.

# %%
import numpy as np
import pandas as pd
import csv
from sklearn.naive_bayes import BernoulliNB,GaussianNB,MultinomialNB
from sklearn.model_selection import cross_val_score


def SampleData(dataset):
    import pandas as pd
    df=pd.read_csv(dataset, encoding = "ISO-8859-1")
    #with pd.option_context('max_colwidth',160):
        #display(df.head())
    return df.head()


def createVocabList(dataSet):
    vocabSet=set([])
    for document in dataSet:
        vocabSet=vocabSet|set(document)
    return list(vocabSet)

def vecVocab(vocabList,inputSet):
    returnVec=[0]*len(vocabList)
    for word in inputSet:
        if word in vocabList:
            returnVec[vocabList.index(word)]=1
        else: print('the word: %s is not in my Vocabulary' % word)
    return returnVec

def textParse(bigString):
    import re
    #listOfTokens=re.split(r'\W*',bigString)
    listOfTokens=re.split(r'[^A-Za-z]+',bigString)
    return [tok.lower() for tok in listOfTokens if len(tok)>2]

def featDataset(dataset):

    output=dataset[:-4]+'_Vectorized.txt'
    with open(output,"w") as w:
        with open(dataset,'r', encoding='utf-8-sig') as f:
            rows = csv.reader(f, (line.replace('\r', '') for line in f))
            labels = [row[0] for row in rows]
            f.seek(0)
            text = [row[1] for row in rows]
            
            #print(text)
            #print(labels)
            parsedText=list(map(textParse,text))            
            vocabList=createVocabList(parsedText)
            for word in vocabList:
                w.write(word+',')
            w.write('class\n')
            for i in range(len(labels)):
                returnVec=vecVocab(vocabList,parsedText[i])
                for num in returnVec:
                    w.write(str(num)+',')
                w.write(labels[i]+"\n")
            return(vocabList)        

def loadDataSet(dataset): 
    with open(dataset) as f:
        data=f.readlines()
        attributes=data[0].rstrip().split(',')[:-1]
        #print("attributes",len(attributes))
        instances=[entry.rstrip().split(',')[:-1] for entry in data[1:]]
        dataArray=[]
        for i in range(len(instances[0])):
            try:
                dataArray.append([float(instance[i]) for instance in instances])
            except:
                encodedData,codeBook=encode([instance[i] for instance in instances])
                dataArray.append(encodedData)
                print(attributes[i],': ',list(codeBook.items()))
        instances=np.array(dataArray).T
        labels=[entry.rstrip().split(',')[-1] for entry in data[1:]]
        #print(instances,labels)
        return instances,labels

def predict(testset):
    if "clf_B" in globals():
        prediction=clf_B.predict(testset)
        print("BernoulliNB: ",prediction)
    if "clf_G" in globals():
        prediction=clf_G.predict(testset)
        print("GaussianNB: ",prediction)
    if "clf_M" in globals():
        prediction=clf_M.predict(testset)
        print("MultinomialNB: ",prediction)
        
        
def predict_csv(testset):
    dict_list=[]
    fnames = ['Text','BernoulliNB_result','GaussianNB_Result','MultinomialNB_result']

    with open(testset,'r', encoding='utf-8-sig') as f:
        rows = csv.reader(f, (line.replace('\r', '') for line in f))
        text = [row[0] for row in rows]
        #print(text)
        parsedText=list(map(textParse,text))
        for t in text:
            returnVec=vecVocab(vocabList,textParse(t))
            feat_t=np.array(returnVec).reshape(1, -1)
            B_result = str(clf_B.predict(feat_t)).strip("['']")
            G_result = str(clf_G.predict(feat_t)).strip("['']")
            M_result = str(clf_M.predict(feat_t)).strip("['']")
                
            result_dict={'Text': t, 'BernoulliNB_result': B_result, 'GaussianNB_Result': G_result, 'MultinomialNB_result': M_result}
            dict_list.append(result_dict)
            
            
        with open(outFile, 'w') as of:
            writer = csv.DictWriter(of, fieldnames=fnames)
            writer.writeheader()
            
            for result_dict in dict_list:
                writer.writerow(result_dict)

# %%
#Sample the train dataset
dataset = 'train_set.csv'
sample = SampleData(dataset)
print(sample)

#generate the vocab list
text=[instance.rstrip() for instance in sample.iloc[:,1]]
parsedText=list(map(textParse,text))
vocabList=createVocabList(parsedText)
#print('Vocabulary List: \n',vocabList)

#featurize(vectorize) dataset
vocabList=featDataset(dataset)
print('The featurization is done!')
# Out:
#   class                                            content
# 0    No                            Landmark Center, 8th Fl
# 1    No  Contact: The C3 team at MakemeC3@cic.us -- Add...
# 2    No  A powerful tool for developers, the MySQL Data...
# 3    No              Easy access to T, Hubway, and parking
# 4   Yes                      Check out our Private Offices
# The featurization is done!

# %% [markdown]
# # Evaluate 3 different classifiers
#
# We used 3 different algorithms to do the classification.
#
# The block below uses k-fold cross validation to calculate the accuracy of each algorithm, so that we could later adopt the algorithm that performs the best in this case.

# %%
#Evaluate different classifiers

instances, labels = loadDataSet(dataset[:-4]+'_Vectorized.txt')

clf_B = BernoulliNB()
clf_B.fit(instances, labels)

clf_G = GaussianNB()
clf_G.fit(instances, labels)

clf_M = MultinomialNB()
clf_M.fit(instances, labels)

n_foldCV = 5
B_scores = cross_val_score(clf_B, instances, labels, cv=n_foldCV)

print("======BernoulliNB======")
print(B_scores)
print("Accuracy: %0.2f (+/- %0.2f)" % (B_scores.mean(), B_scores.std() * 2))

G_scores = cross_val_score(clf_G, instances, labels, cv=n_foldCV)
print("======GaussianNB======")
print(G_scores)
print("Accuracy: %0.2f (+/- %0.2f)" % (G_scores.mean(), G_scores.std() * 2))
        
M_scores = cross_val_score(clf_M, instances, labels, cv=n_foldCV)
print("======MultinomialNB======")
print(M_scores)
print("Accuracy: %0.2f (+/- %0.2f)" % (M_scores.mean(), M_scores.std() * 2))
# Out:
# ======BernoulliNB======
# [0.58823529 0.8        0.8        0.8        0.71428571]
# Accuracy: 0.74 (+/- 0.17)
# ======GaussianNB======
# [0.64705882 0.73333333 0.66666667 0.66666667 0.92857143]
# Accuracy: 0.73 (+/- 0.21)
# ======MultinomialNB======
# [0.76470588 0.66666667 0.8        0.6        0.78571429]
# Accuracy: 0.72 (+/- 0.15)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:657: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:657: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py:657: Warning: The least populated class in y has only 1 members, which is too few. The minimum number of members in any class cannot be less than n_splits=5.
#   % (min_groups, self.n_splits)), Warning)

# %% [markdown]
# # Predict results
#
# The block below performs all three classifiers and generate 3 columns in the output csv file to present the results of the prediction.
#
# For 'testset', input the csv file which contains the the text that you want to predict.
#
# For 'outFile', enter the out put file name.
# For the sample output, see test_set_predict.csv

# %%
#predict results

testset = 'test_set.csv'
outFile = 'test_set_predict.csv'

predict_csv(testset)
print('Prediction finished')
# Out:
# the word: workshop is not in my Vocabulary
# the word: brookline is not in my Vocabulary
# the word: lots is not in my Vocabulary
# the word: micro is not in my Vocabulary
# the word: off is not in my Vocabulary
# the word: beacon is not in my Vocabulary
# the word: solopreneurs is not in my Vocabulary
# the word: telecommuters is not in my Vocabulary
# the word: required is not in my Vocabulary
# the word: notice is not in my Vocabulary
# the word: leave is not in my Vocabulary
# the word: tell is not in my Vocabulary
# the word: deposit is not in my Vocabulary
# the word: required is not in my Vocabulary
# the word: insurance is not in my Vocabulary
# the word: certificate is not in my Vocabulary
# the word: required is not in my Vocabulary
# the word: default is not in my Vocabulary
# the word: theme is not in my Vocabulary
# the word: presents is not in my Vocabulary
# the word: clear is not in my Vocabulary
# the word: concise is not in my Vocabulary
# the word: beautiful is not in my Vocabulary
# the word: form is not in my Vocabulary
# the word: making is not in my Vocabulary
# the word: read is not in my Vocabulary
# the word: interpret is not in my Vocabulary
# the word: glance is not in my Vocabulary
# the word: special is not in my Vocabulary
# the word: multi is not in my Vocabulary
# the word: menberships is not in my Vocabulary
# the word: avaiable is not in my Vocabulary
# the word: january is not in my Vocabulary
# the word: marked is not in my Vocabulary
# the word: opening is not in my Vocabulary
# the word: brought is not in my Vocabulary
# the word: face is not in my Vocabulary
# the word: video is not in my Vocabulary
# the word: turnstone is not in my Vocabulary
# the word: bar is not in my Vocabulary
# the word: none is not in my Vocabulary
# the word: command is not in my Vocabulary
# the word: api is not in my Vocabulary
# the word: sysadmin is not in my Vocabulary
# the word: defaults is not in my Vocabulary
# the word: auditing is not in my Vocabulary
# the word: unmatched is not in my Vocabulary
# the word: confident is not in my Vocabulary
# the word: professional is not in my Vocabulary
# the word: feel is not in my Vocabulary
# the word: customers is not in my Vocabulary
# the word: demand is not in my Vocabulary
# the word: confidence is not in my Vocabulary
# the word: come is not in my Vocabulary
# the word: started is not in my Vocabulary
# the word: could is not in my Vocabulary
# the word: climb is not in my Vocabulary
# the word: wall is not in my Vocabulary
# the word: didn is not in my Vocabulary
# the word: seem is not in my Vocabulary
# the word: abby is not in my Vocabulary
# the word: taylor is not in my Vocabulary
# the word: partnership is not in my Vocabulary
# the word: action is not in my Vocabulary
# the word: seeing is not in my Vocabulary
# the word: chaos is not in my Vocabulary
# the word: keeps is not in my Vocabulary
# the word: helps is not in my Vocabulary
# the word: super is not in my Vocabulary
# the word: zen is not in my Vocabulary
# the word: feel is not in my Vocabulary
# the word: relaxing is not in my Vocabulary
# the word: spa is not in my Vocabulary
# the word: taken is not in my Vocabulary
# the word: personality is not in my Vocabulary
# the word: gallery is not in my Vocabulary
# the word: neighbors is not in my Vocabulary
# the word: only is not in my Vocabulary
# the word: holds is not in my Vocabulary
# the word: art is not in my Vocabulary
# the word: receptions is not in my Vocabulary
# the word: rotating is not in my Vocabulary
# the word: various is not in my Vocabulary
# the word: let is not in my Vocabulary
# the word: grow is not in my Vocabulary
# the word: together is not in my Vocabulary
# the word: founding is not in my Vocabulary
# the word: member is not in my Vocabulary
# the word: build is not in my Vocabulary
# the word: shape is not in my Vocabulary
# the word: proud is not in my Vocabulary
# the word: little is not in my Vocabulary
# the word: mac is not in my Vocabulary
# the word: delegation is not in my Vocabulary
# the word: administration is not in my Vocabulary
# the word: tasks is not in my Vocabulary
# the word: manages is not in my Vocabulary
# the word: users is not in my Vocabulary
# the word: groups is not in my Vocabulary
# the word: databases is not in my Vocabulary
# the word: bind is not in my Vocabulary
# the word: apache is not in my Vocabulary
# the word: postfix is not in my Vocabulary
# the word: sendmail is not in my Vocabulary
# the word: qmail is not in my Vocabulary
# the word: backups is not in my Vocabulary
# the word: firewalls is not in my Vocabulary
# the word: much is not in my Vocabulary
# the word: post is not in my Vocabulary
# the word: waterman is not in my Vocabulary
# the word: come is not in my Vocabulary
# the word: typical is not in my Vocabulary
# the word: silicon is not in my Vocabulary
# the word: valley is not in my Vocabulary
# the word: says is not in my Vocabulary
# the word: come is not in my Vocabulary
# the word: looking is not in my Vocabulary
# the word: entrepreneurially is not in my Vocabulary
# the word: incumbent is not in my Vocabulary
# the word: deep is not in my Vocabulary
# the word: necessary is not in my Vocabulary
# the word: tech is not in my Vocabulary
# the word: scaling is not in my Vocabulary
# the word: way is not in my Vocabulary
# the word: harder is not in my Vocabulary
# the word: learn is not in my Vocabulary
# the word: nuances is not in my Vocabulary
# the word: oil is not in my Vocabulary
# the word: gas is not in my Vocabulary
# the word: build is not in my Vocabulary
# the word: responsive is not in my Vocabulary
# the word: teach is not in my Vocabulary
# the word: latter is not in my Vocabulary
# the word: canopy is not in my Vocabulary
# the word: canopy is not in my Vocabulary
# the word: emphasizes is not in my Vocabulary
# the word: off is not in my Vocabulary
# the word: davis is not in my Vocabulary
# the word: insert is not in my Vocabulary
# the word: links is not in my Vocabulary
# the word: pages is not in my Vocabulary
# the word: uploaded is not in my Vocabulary
# the word: files is not in my Vocabulary
# the word: then is not in my Vocabulary
# the word: juggernaut is not in my Vocabulary
# the word: worldwide is not in my Vocabulary
# the word: york is not in my Vocabulary
# the word: firm is not in my Vocabulary
# the word: intends is not in my Vocabulary
# the word: another is not in my Vocabulary
# the word: downtown is not in my Vocabulary
# the word: early is not in my Vocabulary
# the word: week is not in my Vocabulary
# the word: announced is not in my Vocabulary
# the word: planning is not in my Vocabulary
# the word: rock is not in my Vocabulary
# the word: climbing is not in my Vocabulary
# the word: overlooking is not in my Vocabulary
# the word: brooklyn is not in my Vocabulary
# the word: boulders is not in my Vocabulary
# the word: would is not in my Vocabulary
# the word: please is not in my Vocabulary
# the word: link is not in my Vocabulary
# the word: bus is not in my Vocabulary
# the word: train is not in my Vocabulary
# the word: terminal is not in my Vocabulary
# the word: easily is not in my Vocabulary
# the word: accessible is not in my Vocabulary
# the word: locals is not in my Vocabulary
# the word: town is not in my Vocabulary
# the word: travelers is not in my Vocabulary
# the word: march is not in my Vocabulary
# the word: vibrant is not in my Vocabulary
# the word: neighborhood is not in my Vocabulary
# the word: nightlife is not in my Vocabulary
# the word: green is not in my Vocabulary
# the word: geek is not in my Vocabulary
# the word: premium is not in my Vocabulary
# the word: geek is not in my Vocabulary
# the word: offers is not in my Vocabulary
# the word: cubicle is not in my Vocabulary
# the word: boss is not in my Vocabulary
# the word: cubicles is not in my Vocabulary
# the word: sign is not in my Vocabulary
# the word: geek is not in my Vocabulary
# the word: casual is not in my Vocabulary
# the word: member is not in my Vocabulary
# the word: days is not in my Vocabulary
# the word: shaping is not in my Vocabulary
# the word: workforce is not in my Vocabulary
# the word: initiated is not in my Vocabulary
# the word: decades is not in my Vocabulary
# the word: accelerated is not in my Vocabulary
# the word: recession is not in my Vocabulary
# the word: laid is not in my Vocabulary
# the word: off is not in my Vocabulary
# the word: shifted is not in my Vocabulary
# the word: contract is not in my Vocabulary
# the word: offers is not in my Vocabulary
# the word: flexibility is not in my Vocabulary
# the word: grow is not in my Vocabulary
# the word: shrink is not in my Vocabulary
# the word: without is not in my Vocabulary
# the word: hassling is not in my Vocabulary
# the word: leases is not in my Vocabulary
# the word: electric is not in my Vocabulary
# the word: bills is not in my Vocabulary
# the word: established is not in my Vocabulary
# the word: finding is not in my Vocabulary
# the word: having is not in my Vocabulary
# the word: foothold is not in my Vocabulary
# the word: hip is not in my Vocabulary
# the word: helps is not in my Vocabulary
# the word: appeal is not in my Vocabulary
# the word: millennials is not in my Vocabulary
# the word: disinclined is not in my Vocabulary
# the word: job is not in my Vocabulary
# the word: burbs is not in my Vocabulary
# the word: while is not in my Vocabulary
# the word: allowing is not in my Vocabulary
# the word: inhale is not in my Vocabulary
# the word: buzz is not in my Vocabulary
# the word: usermin is not in my Vocabulary
# the word: webmail is not in my Vocabulary
# the word: much is not in my Vocabulary
# the word: usermin is not in my Vocabulary
# the word: featured is not in my Vocabulary
# the word: webmail is not in my Vocabulary
# the word: client is not in my Vocabulary
# the word: encryption is not in my Vocabulary
# the word: search is not in my Vocabulary
# the word: spam is not in my Vocabulary
# the word: antivirus is not in my Vocabulary
# the word: mail is not in my Vocabulary
# the word: filters is not in my Vocabulary
# the word: folders is not in my Vocabulary
# the word: usermin is not in my Vocabulary
# the word: grant is not in my Vocabulary
# the word: privileges is not in my Vocabulary
# the word: users is not in my Vocabulary
# the word: password is not in my Vocabulary
# the word: managing is not in my Vocabulary
# the word: databases is not in my Vocabulary
# the word: managing is not in my Vocabulary
# the word: editing is not in my Vocabulary
# the word: files is not in my Vocabulary
# the word: much is not in my Vocabulary
# the word: another is not in my Vocabulary
# the word: webmail is not in my Vocabulary
# the word: usermin is not in my Vocabulary
# the word: might is not in my Vocabulary
# Prediction finished
